# %%
#     String consumerKey = "QsOERsP4j8omcD1I6NgKX3aMv";//specify the consumer key from the twitter app
#     String consumerSecret = "VGwSK6jIdju52M2Q8zYCxpQxzZilowN3Fw6iGGMhD60lXEllXy";//specify the consumerSecret key from the twitter app
#     String token = "332872784-J36ms73TPAiEbuGULRMeIRfuR0ql4GLzYVdmvUSZ";//specify the token key from the twitter app
#     String secret = "DTUyE8t90hCnEa8CFNzqqVhC8a2dA4s7vEndcmQHOR92f";//specify the secret key from the twitter app

# %%
access_token = "332872784-J36ms73TPAiEbuGULRMeIRfuR0ql4GLzYVdmvUSZ"
access_token_secret = "DTUyE8t90hCnEa8CFNzqqVhC8a2dA4s7vEndcmQHOR92f"
consumer_key = "QsOERsP4j8omcD1I6NgKX3aMv"
consumer_secret = "VGwSK6jIdju52M2Q8zYCxpQxzZilowN3Fw6iGGMhD60lXEllXy"

# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
from kafka import KafkaProducer
producer = KafkaProducer(bootstrap_servers='localhost:9092') #Same port as your Kafka server

# %%
topic_name = "twitter-tweets"

# %%
class twitterAuth():
    """SET UP TWITTER AUTHENTICATION"""

    def authenticateTwitterApp(self):
        auth = OAuthHandler(consumer_key, consumer_secret)
        auth.set_access_token(access_token, access_token_secret)

        return auth

# %%
class TwitterStreamer():

    """SET UP STREAMER"""
    def __init__(self):
        self.twitterAuth = twitterAuth()

    def stream_tweets(self):
        while True:
            listener = ListenerTS() 
            auth = self.twitterAuth.authenticateTwitterApp()
            stream = Stream(auth, listener)
            stream.filter(track=["Apple"], stall_warnings=True, languages= ["en"])

# %%
class ListenerTS(StreamListener):

    def on_data(self, raw_data):
            producer.send(topic_name, str.encode(raw_data))
            return True

# %%
if __name__ == "__main__":
    TS = TwitterStreamer()
    TS.stream_tweets()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-e269065649ea> in <module>
#       1 if __name__ == "__main__":
#       2     TS = TwitterStreamer()
# ----> 3     TS.stream_tweets()
#
# <ipython-input-5-d98673a6fd2e> in stream_tweets(self)
#      10             auth = self.twitterAuth.authenticateTwitterApp()
#      11             stream = Stream(auth, listener)
# ---> 12             stream.filter(track=["Apple"], stall_warnings=True, languages= ["en"])
#
# ~/Personal/github.com/ArpanMajumdar/Real-time-Twitter-Sentiment-Analysis/venv/lib/python3.8/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# ...
